# %%
from PIL import Image
import requests
import time
from Adv_CLIP.model import get_model, get_processor

model = get_model()
model.to("cuda")
processor = get_processor()
# Print on which device the model is
print(model.device)

# %% [markdown]
# ## Checking out CLIP

# %%
# Create function to pass input image and text to model and return the label probabilities
import torch

def get_label_probs(image, text, model, processor):
    torch.cuda.empty_cache()  # Release cached memory
    inputs = processor(text=text, images=image, return_tensors="pt", padding=True)
    inputs = inputs.to("cuda")
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image
    probs = logits_per_image.softmax(dim=1)
    # Clear GPU memory
    del inputs, outputs, logits_per_image
    torch.cuda.empty_cache()  # Release cached memory
    return probs


im = "dog.jpg"
image = Image.open(im)
text=["a photo of a cat", "a photo of a dog"]

# Get label probabilities for the image and text
start = time.time()
probs = get_label_probs(image, text, model, processor)
end = time.time()
print(f"Time taken: {end-start}")
print(probs)
# Out:
# Time taken: 0.3101058006286621
# tensor([[0.0023, 0.9977]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
# Load JSON file with image URLs and text
import json
with open("zocket_brand_ads.json", "r") as f:
    data = json.load(f)
    
print(data['entries'][0])
# Out:
# {'name': 'Kamalnath', 'brand_name': 'Nike', 'brand_logo': 'https://d273i1jagfl543.cloudfront.net/production/media/business/EfIGoRK_Yw42--5mcx3wA.jpg', 'product_name': 'The Classic Space Patty Burgers', 'url': 'https://d273i1jagfl543.cloudfront.net/production/media/product/ComfyUI_01657_.jpg'}

# %%
# Extract entries which have "https://cdn.shopify.com/" as part of the image URL
entries = [entry for entry in data['entries'] if "https://cdn.shopify.com/" in entry['url']]
len(entries)
# Out:
# 110748

# %%
import matplotlib.pyplot as plt

# Load image from URL
print(entries[3]['url'])
image = Image.open(requests.get(entries[3]['url'], stream=True).raw)
# Plot image
plt.imshow(image)
# Out:
# https://cdn.shopify.com/s/files/1/0668/7588/3752/products/Main_b9e0da7f-db89-4d41-83f0-7f417b02831d.jpg?v=1696917084

# %%
image = Image.open(requests.get(entries[3]['url'], stream=True).raw)
text = ['Ad Creative with text', 'Ad Creative with No text']

output = get_label_probs(image, text, model, processor)

output
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[17], line 4
#       1 image = Image.open(requests.get(entries[3]['url'], stream=True).raw)
#       2 text = ['Ad Creative with text', 'Ad Creative with No text']
# ----> 4 output = get_label_probs(image, text, model, processor)
#       6 output
#
# Cell In[10], line 8, in get_label_probs(image, text, model, processor)
#       6 inputs = processor(text=text, images=image, return_tensors="pt", padding=True)
#       7 inputs = inputs.to("cuda")
# ----> 8 outputs = model(**inputs)
#       9 logits_per_image = outputs.logits_per_image
#      10 probs = logits_per_image.softmax(dim=1)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:1110, in CLIPModel.forward(self, input_ids, pixel_values, attention_mask, position_ids, return_loss, output_attentions, output_hidden_states, return_dict)
#    1105 output_hidden_states = (
#    1106     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1107 )
#    1108 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1110 vision_outputs = self.vision_model(
#    1111     pixel_values=pixel_values,
#    1112     output_attentions=output_attentions,
#    1113     output_hidden_states=output_hidden_states,
#    1114     return_dict=return_dict,
#    1115 )
#    1117 text_outputs = self.text_model(
#    1118     input_ids=input_ids,
#    1119     attention_mask=attention_mask,
#    (...)
#    1123     return_dict=return_dict,
#    1124 )
#    1126 image_embeds = vision_outputs[1]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:852, in CLIPVisionTransformer.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict)
#     849 hidden_states = self.embeddings(pixel_values)
#     850 hidden_states = self.pre_layrnorm(hidden_states)
# --> 852 encoder_outputs = self.encoder(
#     853     inputs_embeds=hidden_states,
#     854     output_attentions=output_attentions,
#     855     output_hidden_states=output_hidden_states,
#     856     return_dict=return_dict,
#     857 )
#     859 last_hidden_state = encoder_outputs[0]
#     860 pooled_output = last_hidden_state[:, 0, :]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:638, in CLIPEncoder.forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     630     layer_outputs = self._gradient_checkpointing_func(
#     631         encoder_layer.__call__,
#     632         hidden_states,
#    (...)
#     635         output_attentions,
#     636     )
#     637 else:
# --> 638     layer_outputs = encoder_layer(
#     639         hidden_states,
#     640         attention_mask,
#     641         causal_attention_mask,
#     642         output_attentions=output_attentions,
#     643     )
#     645 hidden_states = layer_outputs[0]
#     647 if output_attentions:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:380, in CLIPEncoderLayer.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     377 residual = hidden_states
#     379 hidden_states = self.layer_norm1(hidden_states)
# --> 380 hidden_states, attn_weights = self.self_attn(
#     381     hidden_states=hidden_states,
#     382     attention_mask=attention_mask,
#     383     causal_attention_mask=causal_attention_mask,
#     384     output_attentions=output_attentions,
#     385 )
#     386 hidden_states = residual + hidden_states
#     388 residual = hidden_states
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:305, in CLIPAttention.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     302     attn_weights = attn_weights.view(bsz, self.num_heads, tgt_len, src_len) + attention_mask
#     303     attn_weights = attn_weights.view(bsz * self.num_heads, tgt_len, src_len)
# --> 305 attn_weights = nn.functional.softmax(attn_weights, dim=-1)
#     307 if output_attentions:
#     308     # this operation is a bit akward, but it's required to
#     309     # make sure that attn_weights keeps its gradient.
#     310     # In order to do so, attn_weights have to reshaped
#     311     # twice and have to be reused in the following
#     312     attn_weights_reshaped = attn_weights.view(bsz, self.num_heads, tgt_len, src_len)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:1858, in softmax(input, dim, _stacklevel, dtype)
#    1856     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1857 if dtype is None:
# -> 1858     ret = input.softmax(dim)
#    1859 else:
#    1860     ret = input.softmax(dim, dtype=dtype)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 3.81 GiB of which 10.69 MiB is free. Including non-PyTorch memory, this process has 3.80 GiB memory in use. Of the allocated memory 3.71 GiB is allocated by PyTorch, and 6.20 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Zocket Generated Image, Grouping the entries by brand

# %%
from collections import defaultdict
import json

grouped_entries = defaultdict(lambda: {"name": "", "brand_name": "", "brand_logo": "", "products": []})

for entry in entries:
    brand_name = entry['brand_name']
    grouped_entries[brand_name]['name'] = entry['name']
    grouped_entries[brand_name]['brand_name'] = brand_name
    grouped_entries[brand_name]['brand_logo'] = entry['brand_logo']
    product_info = {"product_name": entry["product_name"], "url": entry["url"]}
    grouped_entries[brand_name]['products'].append(product_info)

# Convert defaultdict to list of dictionaries with products
grouped_entries_list = list(grouped_entries.values())

# Print or use grouped_entries_list as needed

# Save grouped_entries_list to a JSON file
with open('zocket_grouped_entries_2.json', 'w') as json_file:
    json.dump(grouped_entries_list, json_file, indent=2)

# %%
len(grouped_entries_list[1]['products'])

total = 0
out_a = []
for i in range(len(grouped_entries_list)):
    out_a.append([grouped_entries_list[i]['brand_name'], len(grouped_entries_list[i]['products'])])
    total += len(grouped_entries_list[i]['products'])
    
print(total, out_a)
# Out:
# 110748 [['Baskin Robins', 45], ['app-security', 1814], ['ShopifyStoreAppreview', 113], ['Kim3 USA', 107], ['Axor', 45], ['Quickstart (90c2e259)', 45], ['testzocket', 2], ['FreewheelFiesta', 45], ['TestDhanush', 45], ['Kim1 Canada', 16], ['Shopify test', 126], ['Fashlia', 262], ['Namma Grocery', 272], ['LuxLifeGlitter', 18], ['Hundselen.se', 61], ['ElinaFashion.com', 1676], ['Test', 2], ['ZaiBanZ', 233], ['fuelld.co.nz', 43], ['InArt-Studio', 243], ['hoppiie', 42], ['Mitusy™', 80], ['Right4Paws', 47], ['Snapdeals Store', 43], ['Fiber Salons', 22], ['IndiFinds Shop', 45], ['Cart Smart', 13], ['rosebearss', 22], ['Animaniac', 16], ['FREEDOM WORLD', 3], ['AngelTime', 300], ['KG LLC ', 224], ['Rockadavers', 266], ['StarryLight', 1], ['The Boutiquee', 24], ['BlueSoni', 13], ['Puma', 27], ['sanbox-zocket', 20], ['AuchShop', 29], ['infinity Glow', 28], ['My Store', 28], ['CoolFit', 70], ['Raven Moon Gift Store', 196], ['mnmorganic', 46], ['Elegance Bazaar ', 31], ['Snowdays.co', 1], ['Celtic Knot', 15], ['Paradox TL Enterprises', 7], ['Homeprivilez', 918], ['Winter Drip', 2], ['Raw Hair UAE ', 53], ['The Celestials', 12], ['Capsan', 1], ['VitalGym', 8], ['roothawks', 21], ['Urban Flare', 5], ['Home_finds', 16], ['ozark three', 12], ['Zadsa', 57], ['Sharmootas', 28], ['Fashionlavha.com', 1123], ['Sunset Deals', 1], ['Major Accessories', 1], ['Biotune™', 1], ['welldonestorefront', 1], ['Gatfom.net', 3], ['Two Papeleria', 121], ['HealthCare Digitals', 5], ['DynamoBrush', 1], ['SHOWROOM DE PARIS', 27], ['Creative Canvas', 12], ['Alponia', 24], ['NextGen Trimmer', 1], ['Free Spirit ', 82], ['PEGASUS ARMOR', 56], ['THEGENZ STORE', 3], ['EWM', 35], ['Venux', 11], ['YEEBALKAN', 24], ['YOUR STORE ', 37], ['Daniels Assured Delivery', 146], ['bagspoon', 33], ['The Useless Pancreas', 729], ['Baby-Comforts', 339], ['SHOPP.us', 879], ['Teenwear.eu', 400], ['Alex-Store', 68], ['MIANIMED', 585], ['PETGS', 746], ['The Eldorado Shop', 283], ["Clyde's World", 42], ['Asimonline ', 195], ['FASAN STOCK', 9], ['The Qrismora', 13], ['CozyPawsDE', 14], ['Jones Sahota Store', 77], ['Bio-Actif ', 58], ['Império Premium', 193], ['Defiance Fuel', 22], ['Aussie Kitchen reno', 412], ['Cheap hut', 1], ['MYWISHBAG', 168], ['DigitalCatalyst', 2], ['CareFree Clothing ', 54], ['Ryge-Butikken', 15], ['Gear Auto', 55], ['KAD PRO LTD', 78], ['Madlen Handmade Madlen CAT', 9], ['Infinitymeta shop', 19], ['The Joy', 1], ['STF DIAMONDS', 79], ['NYLIR Cart', 15], ['Solago', 14], ['Silent Treasure', 11], ['Xclusive', 186], ['AKHS', 1], ['East Coast Supply Co', 251], ['GoMat', 4], ['SwissCorner Shop ', 11], ['omega store', 191], ['Meðvitund Studio', 52], ['GOOD PRICE', 43], ['RêveSTUDIOZ', 17], ['ANIMATEK', 788], ['AfroOriginal', 1], ['Handyzubehör.de', 5], ['ywalking', 10], ['ElectronicsStore', 51], ['Fit By Brugman', 114], ['Mykro', 23], ['SparklyFy', 6], ['Boutique Beauté & Santé', 20], ['Luxury Clothing', 476], ['Barish', 128], ['Cozy Creatures', 1], ['pelashop', 99], ['SkyGloow', 2], ['Accro Home', 61], ['Shoppradical ', 21], ['Store Of Globe', 431], ['TeaSkinPure', 38], ['Bones Shirt Co.', 2], ['JellyGlow', 1], ['Emissa Shop', 16], ['MunziStore', 39], ['Fresh Juice Sport', 2], ['Fortheheck', 21], ['GOING FIFO', 2], ['DynamiCasa', 68], ['Cozy Wear', 121], ['Urbano ', 83], ['Make It Black', 20], ['BROSKEY VIEW', 4], ['GF Accessories', 13], ["Molly's", 54], ['Wishe', 14], ['COLLECTION WITH FAREED ', 2], ['Shop-for-u', 772], ['the infinite isle', 5], ['Newbieart', 1], ['Visionary Vibes', 1], ['RPC Shoes', 1], ['Pak.marina.com', 1], ['TherapyGun.net', 42], ['LuxeLagoon', 16], ['Partners Hair Design', 614], ['Chefio', 57], ['urban classic store', 131], ['The Outlet', 391], ['online store', 235], ['cocina magica', 1], ['THE V', 484], ['Koning Spandoek', 482], ['glitz', 65], ['FlowComfort', 1], ['bebird-fly', 1], ['Medzo', 1], ['Fitversal', 58], ['M.X.S.MAX', 278], ['Shop tes LED ', 8], ['Sac2GO', 107], ['Trendy Swag Market', 432], ['IZSWEET(Fitss4uu', 99], ['GHLAM HAIRLINE', 130], ...

# %%
sorted_data = sorted(out_a, key=lambda x: x[1], reverse=True)

print(sorted_data)
# Out:
# [['TradingCardsMarketplace.com', 24171], ['We Ship it Online', 14754], ['De Moza', 14142], ['Pastel', 6055], ['Kulture', 3533], ['Hikoro', 3286], ['EMBRACE', 3199], ['GermanHeart', 3086], ['app-security', 1814], ['Sammaya', 1683], ['ElinaFashion.com', 1676], ['Scental Blush', 1309], ['Crazy K Farm Pet and Poultry', 1260], ['Fashionlavha.com', 1123], ['S&GSTORE', 1004], ['colorat.eu', 1002], ['Homeprivilez', 918], ['SHOPP.us', 879], ['Mothertip', 848], ['ANIMATEK', 788], ['Shop-for-u', 772], ['PETGS', 746], ['The Useless Pancreas', 729], ['Retrorama', 700], ['Waze Clothing ', 656], ['Partners Hair Design', 614], ['MIANIMED', 585], ['Girl Season Boutique', 555], ['goraw', 533], ['Léa Shop', 520], ['THE V', 484], ['Koning Spandoek', 482], ['Luxury Clothing', 476], ['Forever Hood', 443], ['Trendy Swag Market', 432], ['Store Of Globe', 431], ['Aussie Kitchen reno', 412], ['Teenwear.eu', 400], ['The Outlet', 391], ['Viva Vista Store', 387], ['Targo Auto HU', 356], ['Tech Nexa store', 350], ['Baby-Comforts', 339], ['Viva Variedade', 327], ['Newtecnology', 304], ['AngelTime', 300], ['Curves ZM', 296], ['The Eldorado Shop', 283], ['M.X.S.MAX', 278], ['Best Deals', 273], ['Satiné', 273], ['Namma Grocery', 272], ['Rockadavers', 266], ['Fashlia', 262], ['East Coast Supply Co', 251], ['InArt-Studio', 243], ['online store', 235], ['ZaiBanZ', 233], ['KG LLC ', 224], ['Life Craft Plannerz', 197], ['Raven Moon Gift Store', 196], ['Asimonline ', 195], ['Pets loop ', 194], ['Império Premium', 193], ['BlackBeards Grooming ', 193], ['omega store', 191], ['Xclusive', 186], ['MYWISHBAG', 168], ['Bien-être- Beauté-Santé', 162], ['Daniels Assured Delivery', 146], ['urban classic store', 131], ['GHLAM HAIRLINE', 130], ['Barish', 128], ['Shopify test', 126], ['Two Papeleria', 121], ['Cozy Wear', 121], ['Turi', 120], ['UNAYA', 117], ['KROPEN', 115], ['Fit By Brugman', 114], ['Hyderabadgifts', 114], ['ShopifyStoreAppreview', 113], ['Kim3 USA', 107], ['Sac2GO', 107], ['pelashop', 99], ['IZSWEET(Fitss4uu', 99], ['Brightbuy bazar', 99], ['Emerald', 97], ['Vibe', 94], ['Nicula jewelery', 90], ['Nextbait', 88], ['Lolly Fragrance', 88], ['Urbano ', 83], ['Free Spirit ', 82], ['Mitusy™', 80], ['STF DIAMONDS', 79], ['KAD PRO LTD', 78], ['Jones Sahota Store', 77], ['Nunushoppp', 72], ['CoolFit', 70], ['Alex-Store', 68], ['DynamiCasa', 68], ['glitz', 65], ['Hundselen.se', 61], ['Accro Home', 61], ['Bio-Actif ', 58], ['Fitversal', 58], ['Zadsa', 57], ['Chefio', 57], ['PEGASUS ARMOR', 56], ['Gear Auto', 55], ['CareFree Clothing ', 54], ["Molly's", 54], ['Raw Hair UAE ', 53], ['Meðvitund Studio', 52], ['ElectronicsStore', 51], ['wirago.in', 49], ['Wow Store', 48], ['Indra shop', 48], ['Right4Paws', 47], ['mnmorganic', 46], ['Baskin Robins', 45], ['Axor', 45], ['Quickstart (90c2e259)', 45], ['FreewheelFiesta', 45], ['TestDhanush', 45], ['IndiFinds Shop', 45], ['fuelld.co.nz', 43], ['Snapdeals Store', 43], ['GOOD PRICE', 43], ['hoppiie', 42], ["Clyde's World", 42], ['TherapyGun.net', 42], ['MunziStore', 39], ['TeaSkinPure', 38], ['YOUR STORE ', 37], ['EWM', 35], ['bagspoon', 33], ['Elegance Bazaar ', 31], ['AuchShop', 29], ['infinity Glow', 28], ['My Store', 28], ['Sharmootas', 28], ['Puma', 27], ['SHOWROOM DE PARIS', 27], ['The Boutiquee', 24], ['Alponia', 24], ['YEEBALKAN', 24], ['YungSyke', 24], ['Mykro', 23], ['Trendtrovemarket.store', 23], ['Fiber Salons', 22], ['rosebearss', 22], ['Defiance Fuel', 22], ['annya test app', 22], ['roothawks', 21], ['Shoppradical ', 21], ['Fortheheck', 21], ['Fun Mart', 21], ['sanbox-zocket', 20], ['Boutique Beauté & Santé', 20], ['Make It Black', 20], ['Infinitymeta shop', 19], ['LuxLifeGlitter', 18], ['RêveSTUDIOZ', 17], ['Kim1 Canada', 16], ['Animaniac', 16], ['Home_finds', 16], ['Emissa Shop', 16], ['LuxeLagoon', 16], ['Quickstart (20df3669)', 16], ['Celtic Knot', 15], ['Ryge-Butikken', 15], ['NYLIR Cart', 15], ['CozyPawsDE', 14], ['Solago', 14], ['Wishe', 14], ['Bharat Mart', 14], ['Cart Smart', 13], ['BlueSoni', 13], ['The Qrism ...

# %%
all_img_urls = []
for i in range(253):
    for z in  range(len(grouped_entries_list[i]['products'])):
        all_img_urls.append({'product_name': grouped_entries_list[i]['products'][z]['product_name'], 'url': grouped_entries_list[i]['products'][z]['url']})

# %%
print(len(all_img_urls),"\n", all_img_urls[0])
# Out:
# 110748
#  {'product_name': 'Gift Card-$10', 'url': 'https://cdn.shopify.com/s/files/1/0668/7588/3752/products/gift_card.png?v=1696917083'}

# %%
import random
rand_100_indx = random.sample(range(0, len(all_img_urls)), 100)
rand_100_img_urls = [all_img_urls[i] for i in rand_100_indx]

rand_100_img_urls
# Out:
# [{'product_name': 'Traditional Ethnicwear Dark Red Georgette Floral Print Saree',
#   'url': 'https://cdn.shopify.com/s/files/1/0625/3566/3867/products/3757.jpg?v=1697716265'},
#  {'product_name': '2022 Breathable Knitted Mesh Casual Shoes Lightweight Smart Casual Shoes Office Work Footwear Men Sh',
#   'url': 'https://cdn.shopify.com/s/files/1/0863/1782/6324/products/BHKH-2022-Breathable-Knitted-Mesh-Casual-Shoes-Lightweight-Smart-Casual-Shoes-Office-Work-Footwear-Men-Shoes_31695795-0347-4d2c-abc0-66936ad3529c.webp?v=1708201436'},
#  {'product_name': 'LOS788 - Silver 925 Sterling Silver Earrings with Synthetic Glass Bead in Multi Color',
#   'url': 'https://cdn.shopify.com/s/files/1/0806/1265/5436/files/265519_large_7fbd06c0-11ac-49ee-a06c-3e26c400ee44.png?v=1709288838'},
#  {'product_name': 'Kids – Girls Printed Ankle Leggings Indian Teal',
#   'url': 'https://cdn.shopify.com/s/files/1/1171/0232/products/3_0561b5c3-a1b4-4ee2-a323-e64414df192c.jpg?v=1668408535'},
#  {'product_name': 'USB and Solar Charge Reflective Led Dog Collar',
#   'url': 'https://cdn.shopify.com/s/files/1/0709/8741/5830/files/Screen_Shot_2018-11-14_at_4.56.06_PM.png?v=1699733827'},
#  {'product_name': 'Non-Stick Induction (5-Layer Granite coated) DOSA TAWA',
#   'url': 'https://cdn.shopify.com/s/files/1/0634/5592/0319/products/057A6108.jpg?v=1703657902'},
#  {'product_name': 'Bermuda Sport live',
#   'url': 'https://cdn.shopify.com/s/files/1/0647/7335/7736/files/Sd6a20bc20c264a55869078b02c91b8dfw.webp?v=1709510599'},
#  {'product_name': 'GF Ferre Dark Blue Washed Mid Waist Cotton Denim Straight Jeans',
#   'url': 'https://cdn.shopify.com/s/files/1/0814/4175/1354/products/s-l1600-24-3-df68dd2f-78a.jpg?v=1707783294'},
#  {'product_name': 'Retractable Car Charger,100W 4 in 1 Super Fast Charge Car Phone Charger,Retractable Cables (31.5 Inc',
#   'url': 'https://cdn.shopify.com/s/files/1/0863/1782/6324/products/54a95519c989b8e95ccf3eae34395301.jpg?v=1708201161'},
#  {'product_name': 'Heart Shape Designer Mangalsutra for Women',
#   'url': 'https://cdn.shopify.com/s/files/1/0630/7748/2648/products/1701337548-1554900709.jpg?v=1709023348'},
baseball Card',
#   'url': 'https://cdn.shopify.com/s/files/1/0798/8592/6675/products/1993-score-480-tim-teufel-nm-mt-san-diego-padres-baseball-card-tradingcardsmarketplace-com-2.jpg?v=1704784955'},
#  {'product_name': 'LOA577 - Rhodium + Ruthenium Brass Ring with AAA Grade CZ  in Multi Color',
#   'url': 'https://cdn.shopify.com/s/files/1/0806/1265/5436/files/262433_large_1ff55b8f-5a14-42f5-a0d1-6326d8d9327d.png?v=1709288448'},
#  {'product_name': 'Wholesale Reversible Bonnets Edge Wrap Custom Long Band Satin Hair Silk Bonnet With Ties',
#   'url': 'https://cdn.shopify.com/s/files/1/0863/1782/6324/products/H74570db2299f4232a74f4dbe40579662H.webp?v=1708549318'},
#  {'product_name': 'Pantufa de algodão, ovelhinhas',
#   'url': 'https://cdn.shopify.com/s/files/1/0628/6583/4144/products/S4a5d5ceeb59642e4bb9da2d41475cd5dV.webp?v=1706363417'},
#  {'product_name': '1PC Sports Kneepad Men Women Pressurized Elastic Knee Pads Arthritis Joints Protector Fitness Gear V',
#   'url': 'https://cdn.shopify.com/s/files/1/0812/3400/2267/files/S19cd317bb67f4a44a88c06aaf8b3dc6br_f4dd2589-381f-42f2-bfb3-2a4daf7d7e52.webp?v=1706003186'},
#  {'product_name': 'Bioderma Photoderm Cream Sunscreen SPF 50+ (40ml)',
#   'url': 'https://cdn.shopify.com/s/files/1/0847/9155/8427/files/e7y33BGuYg-1022169_2.webp?v=1705476117'},
#  {'product_name': "De Moza Women's Skirt Black",
#   'url': 'https://cdn.shopify.com/s/files/1/1171/0232/products/P4A4173.jpg?v=1670308846'},
#  {'product_name': 'Multi Function Attractive Digital Watch for Kids and Mens',
#   'url': 'https://cdn.shopify.com/s/files/1/0598/5737/1196/products/1700893155-1951476991.jpg?v=1707514486'},
#  {'product_name': '1988 Donruss #32 Nelson Liriano/ EX RC Rookie Toronto Blue Jays Baseball Card',
#   'url': 'https://cdn.shopify.com/s/files/1/0798/8592/6675/products/1988-donruss-32-nelson-liriano-ex-rc-rookie-toronto-blue-jays-baseball-card-tradingcardsmarketplace-com-2.jpg?v=1704784626'},
#  {'product_name': 'Apricot Hollowed Pattern Knit Round Neck Buttoned Cardigan',
#   'url': 'https://cdn.shopify.com/s/files/1/0583/8808/6858/files/6c14701aa04cbd81.jpg?v=1708105743'},
#  {'product_name': 'XCover Shipping Insurance-variant 16',
#   'url': 'https://cdn.shopify.com/s/files/1/0602/2561/7942/products/971e6528eb7bb2aeb3d88c8dc0987a37_bad98bc9-6ae8-40fe-9a4a-ab8011dcc4c7.png?v=1690553343'},
#  {'product_name': '1991 Upper Deck #516 Mike Fitzgerald NM-MT Montreal Expos Baseball Card',
#   'url': 'https://cdn.shopify.com/s/files/1/0798/8592/6675/products/1991-upper-deck-516-mike-fitzgerald-nm-mt-montreal-expos-baseball-card-tradingcardsmarketplace-com-1.jpg?v=1704784881'}]

# %%
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm 
for i in tqdm(range(len(rand_100_img_urls))):
    print(rand_100_img_urls[i]['url'])
    image = Image.open(requests.get(rand_100_img_urls[i]['url'], stream=True).raw)
    text = ['Ad Creative with text', 'Ad Creative with No text']
    output_label_probs = get_label_probs(image, text)
    
    # Create plot with 100 images, product name and label probabilities
    plt.figure(figsize=(10, 10))
    plt.imshow(image)
    plt.title(f"Product Name: {rand_100_img_urls[i]['product_name']}\nLabel Probabilities: {output_label_probs}")
    plt.show()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# https://cdn.shopify.com/s/files/1/0625/3566/3867/products/3757.jpg?v=1697716265
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[16], line 8
#       6 image = Image.open(requests.get(rand_100_img_urls[i]['url'], stream=True).raw)
#       7 text = ['Ad Creative with text', 'Ad Creative with No text']
# ----> 8 output_label_probs = get_label_probs(image, text)
#      10 # Create plot with 100 images, product name and label probabilities
#      11 plt.figure(figsize=(10, 10))
#
# Cell In[4], line 5, in get_label_probs(image, text)
#       3 inputs = processor(text=text, images=image, return_tensors="pt", padding=True)
#       4 inputs = inputs.to("cuda")
# ----> 5 outputs = model(**inputs)
#       6 logits_per_image = outputs.logits_per_image
#       7 probs = logits_per_image.softmax(dim=1)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:1110, in CLIPModel.forward(self, input_ids, pixel_values, attention_mask, position_ids, return_loss, output_attentions, output_hidden_states, return_dict)
#    1105 output_hidden_states = (
#    1106     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1107 )
#    1108 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1110 vision_outputs = self.vision_model(
#    1111     pixel_values=pixel_values,
#    1112     output_attentions=output_attentions,
#    1113     output_hidden_states=output_hidden_states,
#    1114     return_dict=return_dict,
#    1115 )
#    1117 text_outputs = self.text_model(
#    1118     input_ids=input_ids,
#    1119     attention_mask=attention_mask,
#    (...)
#    1123     return_dict=return_dict,
#    1124 )
#    1126 image_embeds = vision_outputs[1]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:852, in CLIPVisionTransformer.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict)
#     849 hidden_states = self.embeddings(pixel_values)
#     850 hidden_states = self.pre_layrnorm(hidden_states)
# --> 852 encoder_outputs = self.encoder(
#     853     inputs_embeds=hidden_states,
#     854     output_attentions=output_attentions,
#     855     output_hidden_states=output_hidden_states,
#     856     return_dict=return_dict,
#     857 )
#     859 last_hidden_state = encoder_outputs[0]
#     860 pooled_output = last_hidden_state[:, 0, :]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:638, in CLIPEncoder.forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     630     layer_outputs = self._gradient_checkpointing_func(
#     631         encoder_layer.__call__,
#     632         hidden_states,
#    (...)
#     635         output_attentions,
#     636     )
#     637 else:
# --> 638     layer_outputs = encoder_layer(
#     639         hidden_states,
#     640         attention_mask,
#     641         causal_attention_mask,
#     642         output_attentions=output_attentions,
#     643     )
#     645 hidden_states = layer_outputs[0]
#     647 if output_attentions:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:380, in CLIPEncoderLayer.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     377 residual = hidden_states
#     379 hidden_states = self.layer_norm1(hidden_states)
# --> 380 hidden_states, attn_weights = self.self_attn(
#     381     hidden_states=hidden_states,
#     382     attention_mask=attention_mask,
#     383     causal_attention_mask=causal_attention_mask,
#     384     output_attentions=output_attentions,
#     385 )
#     386 hidden_states = residual + hidden_states
#     388 residual = hidden_states
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/clip/modeling_clip.py:305, in CLIPAttention.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     302     attn_weights = attn_weights.view(bsz, self.num_heads, tgt_len, src_len) + attention_mask
#     303     attn_weights = attn_weights.view(bsz * self.num_heads, tgt_len, src_len)
# --> 305 attn_weights = nn.functional.softmax(attn_weights, dim=-1)
#     307 if output_attentions:
#     308     # this operation is a bit akward, but it's required to
#     309     # make sure that attn_weights keeps its gradient.
#     310     # In order to do so, attn_weights have to reshaped
#     311     # twice and have to be reused in the following
#     312     attn_weights_reshaped = attn_weights.view(bsz, self.num_heads, tgt_len, src_len)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:1858, in softmax(input, dim, _stacklevel, dtype)
#    1856     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1857 if dtype is None:
# -> 1858     ret = input.softmax(dim)
#    1859 else:
#    1860     ret = input.softmax(dim, dtype=dtype)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 3.81 GiB of which 10.69 MiB is free. Including non-PyTorch memory, this process has 3.80 GiB memory in use. Of the allocated memory 3.71 GiB is allocated by PyTorch, and 6.20 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
